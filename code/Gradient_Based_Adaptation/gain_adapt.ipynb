# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sim_modules.rnn import RNN
from sim_modules.testfuncs import gen_in_out_one_in_subs

plt.ion()

# %%
N=500

rnn = [RNN(N=N),RNN(N=N)]

# %%
T = 150000
u_in,u_out = gen_in_out_one_in_subs(T,10)

# %%
t = [None]*2
y = [None]*2
X = [None]*2
X_r = [None]*2
X_e = [None]*2
a = [None]*2
dyda = [None]*2
delta_a = [None]*2
w_out = [None]*2
Err = [None]*2
W = [None]*2

for k in range(2):
    t[k],y[k],X[k],X_r[k],X_e[k],a[k],dyda[k],delta_a[k],w_out[k],Err[k],W[k] = rnn[k].learn_gain(u_in,u_out,mode='global_grad_global_gain')
# Out:
# ...
# 100%|██████████| 150000/150000 [00:14<00:00, 10592.96it/s]

# %%
plt.plot(a[0][:,0])
plt.plot(a[1][:,0])

# %%
# Out:
# 1
